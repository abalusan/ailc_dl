# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset 
from torch.utils.data import DataLoader
from typing import List, Tuple, Dict

# %%
#read dataset
data = pd.read_csv('/nfs/site/home/abalusan/wa_1/courses/ailc_dl/5.diabetes.csv')

# %%
#Pre-process data.
#1) Extract i/p(x - all columns except the last) and o/p(y-last column)
# all rows and columns from 0th to the last but one column. And .values converts it into a numpy array
x_np = data.iloc[:,0:-1].values
y_string = list(data.iloc[:,-1])

# %%
#Convert negative/positive strings to 0/1 booleans. 
y_int = list(map(lambda x: 0 if x == 'negative' else 1, y_string))
#Convert y_int to numpy array or torch tensor as list are inefficient when it comes to matrix operations. 
# Ensure dtype of y is same as the dtype of all features in x.
y_np = np.array(y_int, dtype='float64')

# %%
#Normalize the features - Improves training time. 
#Larger values will have more impact on optimization direction and lower values will be neglected. Resulting in the exploding gradients problem.
#Another issue would be, due to larger gradient of a feat., it takes larger steps and reaches the optimal weight corresponding to it sooner than others while the other low valued -
#-features converge slowly. 
#Both these issues increase training time and can be avoided w/ normalization

#We perform feature nomralization w/ standardization technique x_new = (x - mean)/std

sc = StandardScaler()
x_np = sc.fit_transform(x_np) #fit - calculates the mean and std, transform - applies the transformation based on the mean & std. This function does both.

# %%
#Convert numpy arrays to pytorch tensors to work w/ pytorch library
#TODO: Explore different way to converting numpy array to a tensor and their implications
#If we do not unsqueeze the y tensor, it will have a single dimension and it would not be compatible w/ BCE loss. Unsqueeze adds converts y from [768] to [768,1] shape.
x = torch.tensor(x_np)
y = torch.tensor(y_np).unsqueeze(1)

# %%
#Inherit from the dataset class imported from torch.utils.data. If A(B), A inherits from B.
class Dataset(Dataset):

    def __init__(self: Dataset, x: torch.FloatTensor, y: torch.FloatTensor) -> None:
        self.x = x
        self.y = y

    #Overriding this function from the parent Dataset class to work for our custom dataset
    def __getitem__(self: Dataset, index: int) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        return self.x[index], self.y[index]
    
    #Override the function to return the number of rows
    def __len__(self: Dataset) -> int:
        return len(self.x)

# %%
#Create an instance of the function
dataset = Dataset(x, y)
len(dataset)
# Out:
# 768

# %%
#TODO: Explore the shuffle option
#Creating a generator to fetch 'batch_size' samples from the dataset.
train_loader = DataLoader(dataset=dataset,
           batch_size=32,
           shuffle = True)

#print("There is {} batches in the dataset".format(len(train_loader)))

# %%
##NN arch: 7 i/p neurons (each neuron per feat) and 1 o/p neuron (sigmoid) (1 neuron per 1 label prediction). 
## 3 hidden layers 4,4,3.
## The i/p layer has 3 names: fully connected layer, MLP (multi-layer perceptron), linear layer.

#Inherit from the nn.module class
#super() - advantage is that we can extend and modify the behaviour of the parent class method in subclass w/o completely replacing it.
#1) Suppose we want to call the parent class init method, instead of explicitly calling the Parent class method, we can just use super which makes the code more maintainable.
#2) In multiple inheritance case, the super takes care of the correct method resolution order (MRO) and ensures that the parent class's method is only called once.
#3) do_something() is a parent method. We can extend this in sub class like "super().do_something(); <additional lines to extend functionality>"
class Model(nn.Module):
    def __init__(self, input_features: int, output_features: int) -> None:
        super(Model, self).__init__()
        #NN architecture
        #Hidden layers
        self.fc1 = nn.Linear(input_features,5)
        self.fc2 = nn.Linear(5,4)
        self.fc3 = nn.Linear(4,3)
        self.fc4 = nn.Linear(3,output_features)
        #Sigmoid activation for the output layer
        self.sigmoid = nn.Sigmoid()
        #Tanh activation for hidden layers
        self.tanh = nn.Tanh()

    #Forward prop defined and pytorch figures out the backprop & does it automagically. TODO: Custom backprop possible. Why and when would you use it?
    def forward(self, x: torch.FloatTensor) -> torch.FloatTensor:
        out = self.fc1(x)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        out = self.tanh(out)
        out = self.fc4(out)
        out = self.sigmoid(out)
        return out

# %%
#Object of our class
net = Model(7,1)

#BCE loss as this is a binary classification task
#size_average=True says that the losses are averaged over the batch. If not, we get loss per sample. 
criterion = loss = torch.nn.BCELoss(reduction='mean')

#optimizer
optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum= 0.9)

# %%
#Train the neural network
#Hyper-parameters
epochs = 200

#In pytorch we need to use the for loop to train, in tensorflow/keras the fit function automatically does it.
for epoch in range(epochs):
    #The for loop below runs one epoch
    for inputs, labels in train_loader:
        #Already did this, but make this a habit to ensure labels and features are in the same dtype format
        inputs = inputs.float()
        labels = labels.float() 

        #Forward prop. Here, if regular python, we need to explicitly call the forward method in the comment below. But pytorch does this automatically when we pass input to the net object
        outputs = net(inputs)
        #net.forward()
        #Loss calculation
        loss = criterion(outputs, labels)

        #Clear the gradient buffer to ensure that we dont accumulate the gradient. In pytorch, this must be done manually. 
        optimizer.zero_grad() # sets all gradients to 0
        loss.backward() # Perform backprop and calculate gradients
        optimizer.step() # Applies the weight update rule once

    #Accuracy calculation. (tensor <condition> tensor) Every element is compared with the condition and return 1/0 for True/False per that condition 
    output = (outputs>0.5).float() #threshold the output of sigmoid layer
    accuracy = (output == labels).float().mean()
    
    #Print statistics. Epoch+1 as in python epoch starts from 0.
    print(f"Epoch {epoch+1}/{epochs}, Loss: {loss:.3f}, Accuracy: {accuracy:3f}")
# Out:
# Epoch 1/200, Loss: 0.647, Accuracy: 0.656250
# Epoch 2/200, Loss: 0.636, Accuracy: 0.593750
# Epoch 3/200, Loss: 0.663, Accuracy: 0.625000
# Epoch 4/200, Loss: 0.435, Accuracy: 0.812500
# Epoch 5/200, Loss: 0.637, Accuracy: 0.625000
# Epoch 6/200, Loss: 0.575, Accuracy: 0.718750
# Epoch 7/200, Loss: 0.630, Accuracy: 0.656250
# Epoch 8/200, Loss: 0.583, Accuracy: 0.687500
# Epoch 9/200, Loss: 0.387, Accuracy: 0.843750
# Epoch 10/200, Loss: 0.629, Accuracy: 0.750000
# Epoch 11/200, Loss: 0.459, Accuracy: 0.812500
# Epoch 12/200, Loss: 0.387, Accuracy: 0.875000
# Epoch 13/200, Loss: 0.514, Accuracy: 0.750000
# Epoch 14/200, Loss: 0.608, Accuracy: 0.781250
# Epoch 15/200, Loss: 0.509, Accuracy: 0.718750
# Epoch 16/200, Loss: 0.588, Accuracy: 0.718750
# Epoch 17/200, Loss: 0.355, Accuracy: 0.875000
# Epoch 18/200, Loss: 0.403, Accuracy: 0.781250
# Epoch 19/200, Loss: 0.515, Accuracy: 0.781250
# Epoch 20/200, Loss: 0.500, Accuracy: 0.843750
# Epoch 21/200, Loss: 0.439, Accuracy: 0.750000
# Epoch 22/200, Loss: 0.318, Accuracy: 0.937500
# Epoch 23/200, Loss: 0.350, Accuracy: 0.781250
# Epoch 24/200, Loss: 0.539, Accuracy: 0.718750
# Epoch 25/200, Loss: 0.510, Accuracy: 0.625000
# Epoch 26/200, Loss: 0.322, Accuracy: 0.906250
# Epoch 27/200, Loss: 0.378, Accuracy: 0.875000
# Epoch 28/200, Loss: 0.446, Accuracy: 0.812500
# Epoch 29/200, Loss: 0.331, Accuracy: 0.750000
# Epoch 30/200, Loss: 0.295, Accuracy: 0.843750
# Epoch 31/200, Loss: 0.377, Accuracy: 0.781250
# Epoch 32/200, Loss: 0.485, Accuracy: 0.843750
# Epoch 33/200, Loss: 0.465, Accuracy: 0.843750
# Epoch 34/200, Loss: 0.412, Accuracy: 0.812500
# Epoch 35/200, Loss: 0.468, Accuracy: 0.781250
# Epoch 36/200, Loss: 0.281, Accuracy: 0.968750
# Epoch 37/200, Loss: 0.372, Accuracy: 0.781250
# Epoch 38/200, Loss: 0.391, Accuracy: 0.812500
# Epoch 39/200, Loss: 0.529, Accuracy: 0.750000
# Epoch 40/200, Loss: 0.416, Accuracy: 0.875000
# Epoch 41/200, Loss: 0.470, Accuracy: 0.718750
# Epoch 42/200, Loss: 0.360, Accuracy: 0.781250
# Epoch 43/200, Loss: 0.355, Accuracy: 0.781250
# Epoch 44/200, Loss: 0.457, Accuracy: 0.812500
# Epoch 45/200, Loss: 0.272, Accuracy: 0.875000
# Epoch 46/200, Loss: 0.353, Accuracy: 0.875000
# Epoch 47/200, Loss: 0.419, Accuracy: 0.812500
# Epoch 48/200, Loss: 0.353, Accuracy: 0.750000
# Epoch 49/200, Loss: 0.318, Accuracy: 0.875000
# Epoch 50/200, Loss: 0.588, Accuracy: 0.687500
# Epoch 51/200, Loss: 0.381, Accuracy: 0.750000
# Epoch 52/200, Loss: 0.334, Accuracy: 0.875000
# Epoch 53/200, Loss: 0.435, Accuracy: 0.781250
# Epoch 54/200, Loss: 0.408, Accuracy: 0.781250
# Epoch 55/200, Loss: 0.394, Accuracy: 0.812500
# Epoch 56/200, Loss: 0.574, Accuracy: 0.687500
# Epoch 57/200, Loss: 0.411, Accuracy: 0.812500
# Epoch 58/200, Loss: 0.615, Accuracy: 0.656250
# Epoch 59/200, Loss: 0.330, Accuracy: 0.781250
# Epoch 60/200, Loss: 0.215, Accuracy: 0.937500
# Epoch 61/200, Loss: 0.273, Accuracy: 0.843750
# Epoch 62/200, Loss: 0.714, Accuracy: 0.718750
# Epoch 63/200, Loss: 0.522, Accuracy: 0.781250
# Epoch 64/200, Loss: 0.697, Accuracy: 0.625000
# Epoch 65/200, Loss: 0.400, Accuracy: 0.812500
# Epoch 66/200, Loss: 0.400, Accuracy: 0.750000
# Epoch 67/200, Loss: 0.388, Accuracy: 0.875000
# Epoch 68/200, Loss: 0.489, Accuracy: 0.750000
# Epoch 69/200, Loss: 0.328, Accuracy: 0.812500
# Epoch 70/200, Loss: 0.367, Accuracy: 0.906250
# Epoch 71/200, Loss: 0.408, Accuracy: 0.812500
# Epoch 72/200, Loss: 0.388, Accuracy: 0.812500
# Epoch 73/200, Loss: 0.362, Accuracy: 0.875000
# Epoch 74/200, Loss: 0.319, Accuracy: 0.812500
# Epoch 75/200, Loss: 0.611, Accuracy: 0.656250
# Epoch 76/200, Loss: 0.587, Accuracy: 0.750000
# Epoch 77/200, Loss: 0.416, Accuracy: 0.937500
# Epoch 78/200, Loss: 0.283, Accuracy: 0.781250
# Epoch 79/200, Loss: 0.285, Accuracy: 0.875000
# Epoch 80/200, Loss: 0.260, Accuracy: 0.906250
# Epoch 81/200, Loss: 0.530, Accuracy: 0.843750
# Epoch 82/200, Loss: 0.469, Accuracy: 0.812500
# Epoch 83/200, Loss: 0.492, Accuracy: 0.750000
# Epoch 84/200, Loss: 0.332, Accuracy: 0.812500
# Epoch 85/200, Loss: 0.397, Accuracy: 0.750000
# Epoch 86/200, Loss: 0.379, Accuracy: 0.843750
# Epoch 87/200, Loss: 0.504, Accuracy: 0.718750
# Epoch 88/200, Loss: 0.260, Accuracy: 0.906250
# Epoch 89/200, Loss: 0.377, Accuracy: 0.875000
# Epoch 90/200, Loss: 0.482, Accuracy: 0.718750
# Epoch 91/200, Loss: 0.297, Accuracy: 0.843750
# Epoch 92/200, Loss: 0.382, Accuracy: 0.781250
# Epoch 93/200, Loss: 0.375, Accuracy: 0.843750
# Epoch 94/200, Loss: 0.315, Accuracy: 0.875000
# Epoch 95/200, Loss: 0.263, Accuracy: 0.875000
# Epoch 96/200, Loss: 0.394, Accuracy: 0.875000
# Epoch 97/200, Loss: 0.348, Accuracy: 0.812500
# Epoch 98/200, Loss: 0.448, Accuracy: 0.750000
# Epoch 99/200, Loss: 0.392, Accuracy: 0.812500
# Epoch 100/200, Loss: 0.418, Accuracy: 0.781250
# Epoch 101/200, Loss: 0.503, Accuracy: 0.843750
# Epoch 102/200, Loss: 0.392, Accuracy: 0.781250
# Epoch 103/200, Loss: 0.311, Accuracy: 0.812500
# Epoch 104/200, Loss: 0.442, Accuracy: 0.781250
# Epoch 105/200, Loss: 0.188, Accuracy: 0.937500
# Epoch 106/200, Loss: 0.343, Accuracy: 0.812500
# Epoch 107/200, Loss: 0.300, Accuracy: 0.875000
# Epoch 108/200, Loss: 0.276, Accuracy: 0.843750
# Epoch 109/200, Loss: 0.370, Accuracy: 0.750000
# Epoch 110/200, Loss: 0.397, Accuracy: 0.718750
# Epoch 111/200, Loss: 0.455, Accuracy: 0.656250
# Epoch 112/200, Loss: 0.312, Accuracy: 0.875000
# Epoch 113/200, Loss: 0.437, Accuracy: 0.718750
# Epoch 114/200, Loss: 0.206, Accuracy: 0.937500
# Epoch 115/200, Loss: 0.468, Accuracy: 0.781250
# Epoch 116/200, Loss: 0.294, Accuracy: 0.906250
# Epoch 117/200, Loss: 0.489, Accuracy: 0.812500
# Epoch 118/200, Loss: 0.382, Accuracy: 0.812500
# Epoch 119/200, Loss: 0.460, Accuracy: 0.812500
# Epoch 120/200, Loss: 0.562, Accuracy: 0.718750
# Epoch 121/200, Loss: 0.387, Accuracy: 0.812500
# Epoch 122/200, Loss: 0.436, Accuracy: 0.812500
# Epoch 123/200, Loss: 0.295, Accuracy: 0.875000
# Epoch 124/200, Loss: 0.418, Accuracy: 0.812500
# Epoch 125/200, Loss: 0.390, Accuracy: 0.812500
# Epoch 126/200, Loss: 0.482, Accuracy: 0.718750
# Epoch 127/200, Loss: 0.499, Accuracy: 0.750000
# Epoch 128/200, Loss: 0.491, Accuracy: 0.781250
# Epoch 129/200, Loss: 0.367, Accuracy: 0.812500
# Epoch 130/200, Loss: 0.443, Accuracy: 0.812500
# Epoch 131/200, Loss: 0.452, Accuracy: 0.781250
# Epoch 132/200, Loss: 0.292, Accuracy: 0.906250
# Epoch 133/200, Loss: 0.494, Accuracy: 0.781250
# Epoch 134/200, Loss: 0.447, Accuracy: 0.781250
# Epoch 135/200, Loss: 0.365, Accuracy: 0.812500
# Epoch 136/200, Loss: 0.306, Accuracy: 0.875000
# Epoch 137/200, Loss: 0.479, Accuracy: 0.718750
# Epoch 138/200, Loss: 0.247, Accuracy: 0.843750
# Epoch 139/200, Loss: 0.419, Accuracy: 0.750000
# Epoch 140/200, Loss: 0.354, Accuracy: 0.781250
# Epoch 141/200, Loss: 0.378, Accuracy: 0.875000
# Epoch 142/200, Loss: 0.299, Accuracy: 0.843750
# Epoch 143/200, Loss: 0.466, Accuracy: 0.718750
# Epoch 144/200, Loss: 0.302, Accuracy: 0.812500
# Epoch 145/200, Loss: 0.467, Accuracy: 0.812500
# Epoch 146/200, Loss: 0.279, Accuracy: 0.843750
# Epoch 147/200, Loss: 0.471, Accuracy: 0.718750
# Epoch 148/200, Loss: 0.376, Accuracy: 0.812500
# Epoch 149/200, Loss: 0.420, Accuracy: 0.750000
# Epoch 150/200, Loss: 0.442, Accuracy: 0.843750
# Epoch 151/200, Loss: 0.377, Accuracy: 0.687500
# Epoch 152/200, Loss: 0.426, Accuracy: 0.812500
# Epoch 153/200, Loss: 0.388, Accuracy: 0.843750
# Epoch 154/200, Loss: 0.417, Accuracy: 0.687500
# Epoch 155/200, Loss: 0.319, Accuracy: 0.875000
# Epoch 156/200, Loss: 0.382, Accuracy: 0.875000
# Epoch 157/200, Loss: 0.381, Accuracy: 0.718750
# Epoch 158/200, Loss: 0.443, Accuracy: 0.812500
# Epoch 159/200, Loss: 0.461, Accuracy: 0.718750
# Epoch 160/200, Loss: 0.345, Accuracy: 0.781250
# Epoch 161/200, Loss: 0.482, Accuracy: 0.750000
# Epoch 162/200, Loss: 0.637, Accuracy: 0.687500
# Epoch 163/200, Loss: 0.395, Accuracy: 0.843750
# Epoch 164/200, Loss: 0.456, Accuracy: 0.750000
# Epoch 165/200, Loss: 0.617, Accuracy: 0.718750
# Epoch 166/200, Loss: 0.556, Accuracy: 0.750000
# Epoch 167/200, Loss: 0.346, Accuracy: 0.906250
# Epoch 168/200, Loss: 0.510, Accuracy: 0.718750
# Epoch 169/200, Loss: 0.415, Accuracy: 0.875000
# Epoch 170/200, Loss: 0.323, Accuracy: 0.875000
# Epoch 171/200, Loss: 0.432, Accuracy: 0.812500
# Epoch 172/200, Loss: 0.528, Accuracy: 0.812500
# Epoch 173/200, Loss: 0.587, Accuracy: 0.750000
# Epoch 174/200, Loss: 0.395, Accuracy: 0.750000
# Epoch 175/200, Loss: 0.377, Accuracy: 0.781250
# Epoch 176/200, Loss: 0.298, Accuracy: 0.843750
# Epoch 177/200, Loss: 0.358, Accuracy: 0.812500
# Epoch 178/200, Loss: 0.307, Accuracy: 0.937500
# Epoch 179/200, Loss: 0.377, Accuracy: 0.843750
# Epoch 180/200, Loss: 0.291, Accuracy: 0.875000
# Epoch 181/200, Loss: 0.368, Accuracy: 0.781250
# Epoch 182/200, Loss: 0.416, Accuracy: 0.812500
# Epoch 183/200, Loss: 0.310, Accuracy: 0.906250
# Epoch 184/200, Loss: 0.459, Accuracy: 0.781250
# Epoch 185/200, Loss: 0.370, Accuracy: 0.750000
# Epoch 186/200, Loss: 0.524, Accuracy: 0.750000
# Epoch 187/200, Loss: 0.355, Accuracy: 0.812500
# Epoch 188/200, Loss: 0.376, Accuracy: 0.781250
# Epoch 189/200, Loss: 0.376, Accuracy: 0.781250
# Epoch 190/200, Loss: 0.498, Accuracy: 0.750000
# Epoch 191/200, Loss: 0.531, Accuracy: 0.625000
# Epoch 192/200, Loss: 0.376, Accuracy: 0.843750
# Epoch 193/200, Loss: 0.393, Accuracy: 0.843750
# Epoch 194/200, Loss: 0.545, Accuracy: 0.656250
# Epoch 195/200, Loss: 0.518, Accuracy: 0.812500
# Epoch 196/200, Loss: 0.252, Accuracy: 0.875000
# Epoch 197/200, Loss: 0.549, Accuracy: 0.625000
# Epoch 198/200, Loss: 0.268, Accuracy: 0.906250
# Epoch 199/200, Loss: 0.531, Accuracy: 0.718750
# Epoch 200/200, Loss: 0.521, Accuracy: 0.750000

# %%
#Fluctuating accuracy - how to fix it?
# Train, test, val split not performed (So no inference)
